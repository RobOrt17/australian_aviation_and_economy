# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
aviation = pd.read_csv('../australian_aviation_and_economy/data/city_pairs.csv')

# %%
aviation.shape
# Out:
# (82499, 15)

# %%
aviation.head()
# Out:
#    Month AustralianPort ForeignPort         Country  Passengers_In  \
# 0  31048       Adelaide    Auckland     New Zealand         1513.0
# 1  31048       Adelaide     Bahrain         Bahrain           12.0
# 2  31048       Adelaide      Bombay           India            7.0
# 3  31048       Adelaide   Frankfurt         Germany          115.0
# 4  31048       Adelaide      London  United Kingdom         1567.0
#
#    Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 0               42.167             0.311           985.0
# 1                0.000             0.000             5.0
# 2                0.000             0.000             5.0
# 3                0.009             0.000           171.0
# 4                2.800             0.000          1472.0
#
#    Freight_Out_(tonnes)  Mail_Out_(tonnes)  Passengers_Total  \
# 0                18.704              0.924            2498.0
# 1                 0.033              0.000              17.0
# ...

# %% [markdown]
# I will be looking at only passengers IN and OUT, therefore the mail and freight will be dropped from the aviation dataframe

# %% [markdown]
# aviation = aviation.drop(columns=['Month', 'Freight_In_(tonnes)',
#                        'Mail_In_(tonnes)', 'Freight_Out_(tonnes)',
#                        'Mail_Out_(tonnes)', 'Freight_Total_(tonnes)',
#                        'Mail_Total_(tonnes)'])

# %%
aviation.head()
# Out:
#    Month AustralianPort ForeignPort         Country  Passengers_In  \
# 0  31048       Adelaide    Auckland     New Zealand         1513.0
# 1  31048       Adelaide     Bahrain         Bahrain           12.0
# 2  31048       Adelaide      Bombay           India            7.0
# 3  31048       Adelaide   Frankfurt         Germany          115.0
# 4  31048       Adelaide      London  United Kingdom         1567.0
#
#    Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 0               42.167             0.311           985.0
# 1                0.000             0.000             5.0
# 2                0.000             0.000             5.0
# 3                0.009             0.000           171.0
# 4                2.800             0.000          1472.0
#
#    Freight_Out_(tonnes)  Mail_Out_(tonnes)  Passengers_Total  \
# 0                18.704              0.924            2498.0
# 1                 0.033              0.000              17.0
# ...

# %% [markdown]
# All the necessary columns remained in the above table ^^

# %% [markdown]
# I will need to remove data for the year 2021, due to it being an incomplete year and the fact that my economical data set only goes up to the year 2020.

# %%
aviation.tail()
# Out:
#        Month      AustralianPort ForeignPort        Country  Passengers_In  \
# 82494  44287              Sydney   Vancouver         Canada            0.0
# 82495  44287              Sydney  Wellington    New Zealand         1115.0
# 82496  44287              Sydney      Xiamen          China          341.0
# 82497  44287  Toowoomba Wellcamp   Hong Kong  Hong Kong SAR            0.0
# 82498  44287  Toowoomba Wellcamp   Singapore      Singapore            0.0
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 82494              213.348            33.335             0.0
# 82495                2.102             0.000          1808.0
# 82496              189.800             4.200           748.0
# 82497                3.000             0.000             0.0
# 82498                0.000             0.000             0.0
#
#        Freight_Out_(tonnes)  Mail_Out_(tonnes)  Passengers_Total  \
# 82494                12.637               2.15               0.0
# ...

# %%
aviation = aviation[aviation.Year != 1985]

# %%
aviation = aviation[aviation.Year != 1986]

# %%
aviation = aviation[aviation.Year != 1987]

# %%
aviation = aviation[aviation.Year != 1988]

# %%
aviation = aviation[aviation.Year != 1989]

# %%
aviation = aviation[aviation.Year != 2019]

# %%
aviation = aviation[aviation.Year != 2020]

# %%
aviation = aviation[aviation.Year != 2021]

# %%
aviation.head()
# Out:
#        Month AustralianPort ForeignPort      Country  Passengers_In  \
# 11182  32874       Adelaide   Amsterdam  Netherlands            0.0
# 11183  32874       Adelaide      Athens       Greece            9.0
# 11184  32874       Adelaide    Auckland  New Zealand         1378.0
# 11185  32874       Adelaide     Bahrain      Bahrain            1.0
# 11186  32874       Adelaide     Bangkok     Thailand          328.0
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 11182                0.000             0.000            18.0
# 11183                0.000             0.000             9.0
# 11184               14.789             0.827           884.0
# 11185                0.000             0.000             4.0
# 11186                1.700             0.000           341.0
#
#        Freight_Out_(tonnes)  Mail_Out_(tonnes)  Passengers_Total  \
# 11182                 0.014              0.000              18.0
# ...

# %% [markdown]
# ^^ Above shows that 1985-89 were removed

# %%
aviation.tail()
# Out:
#        Month      AustralianPort ForeignPort        Country  Passengers_In  \
# 78473  43435              Sydney       Wuhan          China         1449.0
# 78474  43435              Sydney      Xiamen          China         2878.0
# 78475  43435              Sydney       Xi'an          China         2076.0
# 78476  43435              Sydney   Zhengzhou          China          989.0
# 78477  43435  Toowoomba Wellcamp   Hong Kong  Hong Kong SAR            0.0
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 78473               34.724            16.700          2079.0
# 78474              176.836             7.044          3711.0
# 78475               90.525             0.000          2808.0
# 78476               82.200             0.000          1552.0
# 78477               11.858             0.000             0.0
#
#        Freight_Out_(tonnes)  Mail_Out_(tonnes)  Passengers_Total  \
# 78473                13.404                0.0            3528.0
# ...

# %% [markdown]
# The above shows that the year 2021 data was dropped from the 'aviation' dataframe successfully ^^

# %%
aviation.shape
# Out:
# (67296, 15)

# %% [markdown]
# Reading in my second data set, on economical figures.

# %%
economy = pd.read_csv('../australian_aviation_and_economy/data/gdp_percapita.csv')

# %%
economy.shape
# Out:
# (6606, 4)

# %%
economy.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2018  2190.240321              NaN
# 1     Afghanistan  2017  2202.570851              NaN
# 2     Afghanistan  2016  2200.764487              NaN
# 3     Afghanistan  2015  2212.750899              NaN
# 4     Afghanistan  2014  2249.253738              NaN

# %%
economy = economy.drop(columns=['Value Footnotes'])
economy
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2018  2190.240321
# 1        Afghanistan  2017  2202.570851
# 2        Afghanistan  2016  2200.764487
# 3        Afghanistan  2015  2212.750899
# 4        Afghanistan  2014  2249.253738
# ...              ...   ...          ...
# 6601        Zimbabwe  1994  3263.934978
# 6602        Zimbabwe  1993  3033.504852
# 6603        Zimbabwe  1992  3054.889178
# 6604        Zimbabwe  1991  3426.598094
# 6605        Zimbabwe  1990  3324.348171
#
# [6606 rows x 3 columns]

# %% [markdown]
# vv Changed the names of the columns

# %%
economy = economy.rename(columns={'Value': 'GDP Per Capita - Foreign', 'Country or Area': 'Country'})
economy
# Out:
#           Country  Year  GDP Per Capita - Foreign
# 0     Afghanistan  2018               2190.240321
# 1     Afghanistan  2017               2202.570851
# 2     Afghanistan  2016               2200.764487
# 3     Afghanistan  2015               2212.750899
# 4     Afghanistan  2014               2249.253738
# ...           ...   ...                       ...
# 6601     Zimbabwe  1994               3263.934978
# 6602     Zimbabwe  1993               3033.504852
# 6603     Zimbabwe  1992               3054.889178
# 6604     Zimbabwe  1991               3426.598094
# 6605     Zimbabwe  1990               3324.348171
#
# [6606 rows x 3 columns]

# %%
economy.dtypes
# Out:
# Country                      object
# Year                          int64
# GDP Per Capita - Foreign    float64
# dtype: object

# %%
aus_economy = pd.read_csv('../australian_aviation_and_economy/data/AUS_GDP_per_capita.csv')
aus_economy
# Out:
#     Year  GDP per capita (current US$)
# 0   1990                   18211.50006
# 1   1991                   18821.79526
# 2   1992                   18570.12046
# 3   1993                   17634.53475
# 4   1994                   18046.13648
# 5   1995                   20319.63063
# 6   1996                   21861.32551
# 7   1997                   23468.59683
# 8   1998                   21318.96417
# 9   1999                   20533.03506
# 10  2000                   21679.24784
# 11  2001                   19490.86111
# 12  2002                   20082.48327
# 13  2003                   23447.03100
# 14  2004                   30430.67644
# 15  2005                   33999.24286
# 16  2006                   36044.92281
# 17  2007                   40960.05449
# 18  2008                   49601.65671
# 19  2009                   42772.35917
# 20  2010                   52022.12560
# 21  2011                   62517.83375
# 22  2012                   68012.14790
# ...

# %%
aus_economy = aus_economy.rename(columns={'GDP per capita (current US$)': 'GDP Per Capita - Domestic'})
aus_economy.head()
# Out:
#    Year  GDP Per Capita - Domestic
# 0  1990                18211.50006
# 1  1991                18821.79526
# 2  1992                18570.12046
# 3  1993                17634.53475
# 4  1994                18046.13648

# %%
aus_economy.dtypes
# Out:
# Year                           int64
# GDP Per Capita - Domestic    float64
# dtype: object

# %%
aviation.dtypes
# Out:
# Month                       int64
# AustralianPort             object
# ForeignPort                object
# Country                    object
# Passengers_In             float64
# Freight_In_(tonnes)       float64
# Mail_In_(tonnes)          float64
# Passengers_Out            float64
# Freight_Out_(tonnes)      float64
# Mail_Out_(tonnes)         float64
# Passengers_Total          float64
# Freight_Total_(tonnes)    float64
# Mail_Total_(tonnes)       float64
# Year                        int64
# Month_num                   int64
# dtype: object

# %% [markdown]
# ^^ The 'Year' data type needs to match, in order to merge.

# %%
economy['Year'] = economy['Year'].astype(str).astype(int)
economy.dtypes
# Out:
# Country                      object
# Year                          int32
# GDP Per Capita - Foreign    float64
# dtype: object

# %% [markdown]
# For this dataframe (economy), I will need to extract the GDP per capita($USD), for the the range of years: 1990-2018. This needs to be merged with the aviation dataframe. ^^

# %%
aviation_economy = aviation.merge(economy, how='left', on=['Country','Year'], sort=False)
aviation_economy
# Out:
#        Month      AustralianPort ForeignPort        Country  Passengers_In  \
# 0      32874            Adelaide   Amsterdam    Netherlands            0.0
# 1      32874            Adelaide      Athens         Greece            9.0
# 2      32874            Adelaide    Auckland    New Zealand         1378.0
# 3      32874            Adelaide     Bahrain        Bahrain            1.0
# 4      32874            Adelaide     Bangkok       Thailand          328.0
# ...      ...                 ...         ...            ...            ...
# 67291  43435              Sydney       Wuhan          China         1449.0
# 67292  43435              Sydney      Xiamen          China         2878.0
# 67293  43435              Sydney       Xi'an          China         2076.0
# 67294  43435              Sydney   Zhengzhou          China          989.0
# 67295  43435  Toowoomba Wellcamp   Hong Kong  Hong Kong SAR            0.0
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# ...

# %%
aviation_economy = aviation_economy.merge(aus_economy, how='left', on=['Year'], sort=False)
aviation_economy
# Out:
#        Month      AustralianPort ForeignPort        Country  Passengers_In  \
# 0      32874            Adelaide   Amsterdam    Netherlands            0.0
# 1      32874            Adelaide      Athens         Greece            9.0
# 2      32874            Adelaide    Auckland    New Zealand         1378.0
# 3      32874            Adelaide     Bahrain        Bahrain            1.0
# 4      32874            Adelaide     Bangkok       Thailand          328.0
# ...      ...                 ...         ...            ...            ...
# 67291  43435              Sydney       Wuhan          China         1449.0
# 67292  43435              Sydney      Xiamen          China         2878.0
# 67293  43435              Sydney       Xi'an          China         2076.0
# 67294  43435              Sydney   Zhengzhou          China          989.0
# 67295  43435  Toowoomba Wellcamp   Hong Kong  Hong Kong SAR            0.0
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# ...

# %% [markdown]
# ^^ The above shows that I was able to merge two different economical dataframes on to the aviation dataframe

# %%
aviation_economy.head()
# Out:
#    Month AustralianPort ForeignPort      Country  Passengers_In  \
# 0  32874       Adelaide   Amsterdam  Netherlands            0.0
# 1  32874       Adelaide      Athens       Greece            9.0
# 2  32874       Adelaide    Auckland  New Zealand         1378.0
# 3  32874       Adelaide     Bahrain      Bahrain            1.0
# 4  32874       Adelaide     Bangkok     Thailand          328.0
#
#    Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 0                0.000             0.000            18.0
# 1                0.000             0.000             9.0
# 2               14.789             0.827           884.0
# 3                0.000             0.000             4.0
# 4                1.700             0.000           341.0
#
#    Freight_Out_(tonnes)  Mail_Out_(tonnes)  Passengers_Total  \
# 0                 0.014              0.000              18.0
# 1                 0.000              0.064              18.0
# ...

# %%
aviation_economy.tail()
# Out:
#        Month      AustralianPort ForeignPort        Country  Passengers_In  \
# 67291  43435              Sydney       Wuhan          China         1449.0
# 67292  43435              Sydney      Xiamen          China         2878.0
# 67293  43435              Sydney       Xi'an          China         2076.0
# 67294  43435              Sydney   Zhengzhou          China          989.0
# 67295  43435  Toowoomba Wellcamp   Hong Kong  Hong Kong SAR            0.0
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# 67291               34.724            16.700          2079.0
# 67292              176.836             7.044          3711.0
# 67293               90.525             0.000          2808.0
# 67294               82.200             0.000          1552.0
# 67295               11.858             0.000             0.0
#
#        Freight_Out_(tonnes)  Mail_Out_(tonnes)  Passengers_Total  \
# 67291                13.404                0.0            3528.0
# ...

# %%
aviation_economy['ForeignPort'].unique()
# Out:
# array(['Amsterdam', 'Athens', 'Auckland', 'Bahrain', 'Bangkok', 'Bombay',
#        'Christchurch', 'Denpasar', 'Frankfurt', 'Fukuoka', 'Hong Kong',
#        'Honolulu', 'Kuala Lumpur', 'London', 'Los Angeles', 'Manchester',
#        'Nadi', 'Rome', 'San Francisco', 'Singapore', 'Tokyo', 'Vancouver',
#        'Abu Dhabi', 'Guam', 'Honiara', 'Manila', 'Nagoya', 'Noumea',
#        'Port Moresby', 'Port Vila', 'Suva', 'Wellington', 'Mount Hagen',
#        'Bandar Seri Begawan', 'Kupang', 'Belgrade', 'Chicago',
#        'Cleveland', 'Denver', 'Dubai', 'Harare', 'Houston', 'Jakarta',
#        'Nauru', 'New York', 'Papeete', 'Apia', 'Beijing', 'Buenos Aires',
#        'New Delhi', 'Pago Pago', 'Paris', 'Phuket', 'Rarotonga',
#        'Toronto', 'Vienna', 'Washington', 'Seattle', 'Seoul', 'Malta',
#        'Milan', 'Karachi', 'Tongatapu', 'Miami', 'Boston', 'Penang',
#        'Phoenix', 'Taipei', 'Guangzhou', 'Osaka', 'San Diego',
# ...

# %% [markdown]
# Exploring and cleaning the City and Country names were done in Excel

# %%
aviation_economy['AustralianPort'].unique()
# Out:
# array(['Adelaide', 'Brisbane', 'Cairns', 'Darwin', 'Hobart', 'Melbourne',
#        'Norfolk Island', 'Perth', 'Port Hedland', 'Sydney', 'Townsville',
#        'Christmas Island', 'Broome', 'Gold Coast', 'Newcastle',
#        'Canberra', 'Sunshine Coast', 'Toowoomba Wellcamp'], dtype=object)

# %%
aviation_economy['Country'].unique()
# Out:
# array(['Netherlands', 'Greece', 'New Zealand', 'Bahrain', 'Thailand',
#        'India', 'Indonesia', 'Germany', 'Japan', 'Hong Kong SAR',
#        'United States', 'Malaysia', 'United Kingdom', 'Fiji', 'Italy',
#        'Singapore', 'Canada', 'United Arab Emirates', 'Guam',
#        'Solomon Islands', 'Philippines', 'New Caledonia',
#        'Papua New Guinea', 'Vanuatu', 'Brunei', 'Yugoslavia', 'Zimbabwe',
#        'Nauru', 'Tahiti', 'Western Samoa', 'China', 'Argentina',
#        'American Samoa', 'France', 'Cook Islands', 'Austria', 'Korea',
#        'Malta', 'Pakistan', 'Tonga', 'Taiwan', 'South Africa',
#        'Sri Lanka', 'Wallis Island', 'Russia', 'Mauritius', 'Belgium',
#        'Lebanon', 'Vietnam', 'Egypt', 'Chile', 'Switzerland',
#        'Luxembourg', 'East Timor', 'Niue', 'Ireland', 'Macau', 'Brazil',
#        'Kazakhstan', 'Marshall Islands', 'Qatar', 'Kenya', 'Nigeria',
#        'Kiribati', 'Reunion', 'Turkey', 'Uruguay', 'Laos'], dtype=object)

# %% [markdown]
# Manchester (US) will be dropped from the dataframe

# %%
aviation_economy = aviation_economy[aviation_economy.ForeignPort != 'Manchester (US)']
aviation_economy
# Out:
#        Month      AustralianPort ForeignPort        Country  Passengers_In  \
# 0      32874            Adelaide   Amsterdam    Netherlands            0.0
# 1      32874            Adelaide      Athens         Greece            9.0
# 2      32874            Adelaide    Auckland    New Zealand         1378.0
# 3      32874            Adelaide     Bahrain        Bahrain            1.0
# 4      32874            Adelaide     Bangkok       Thailand          328.0
# ...      ...                 ...         ...            ...            ...
# 67291  43435              Sydney       Wuhan          China         1449.0
# 67292  43435              Sydney      Xiamen          China         2878.0
# 67293  43435              Sydney       Xi'an          China         2076.0
# 67294  43435              Sydney   Zhengzhou          China          989.0
# 67295  43435  Toowoomba Wellcamp   Hong Kong  Hong Kong SAR            0.0
#
#        Freight_In_(tonnes)  Mail_In_(tonnes)  Passengers_Out  \
# ...

# %% [markdown]
# ^^ The above shows that the 2 rows were dropped that contained the city: 'Manchester (US)'

# %%
aviation_economy[aviation_economy.ForeignPort == 'Manchester (US)']
# Out:
# Empty DataFrame
# Columns: [Month, AustralianPort, ForeignPort, Country, Passengers_In, Freight_In_(tonnes), Mail_In_(tonnes), Passengers_Out, Freight_Out_(tonnes), Mail_Out_(tonnes), Passengers_Total, Freight_Total_(tonnes), Mail_Total_(tonnes), Year, Month_num, GDP Per Capita - Foreign, GDP Per Capita - Domestic]
# Index: []

# %% [markdown]
# ^^ Confirming that it was dropped correctly

# %% [markdown]
# Dropping tha unwanted columns vv

# %%
aviation_economy = aviation_economy.drop(columns=['Freight_In_(tonnes)', 
                                                'Mail_In_(tonnes)', 'Freight_Out_(tonnes)', 
                                                'Mail_Out_(tonnes)', 'Freight_Total_(tonnes)',
                                                'Mail_Total_(tonnes)'])
aviation_economy
# Out:
#        Month      AustralianPort ForeignPort        Country  Passengers_In  \
# 0      32874            Adelaide   Amsterdam    Netherlands            0.0
# 1      32874            Adelaide      Athens         Greece            9.0
# 2      32874            Adelaide    Auckland    New Zealand         1378.0
# 3      32874            Adelaide     Bahrain        Bahrain            1.0
# 4      32874            Adelaide     Bangkok       Thailand          328.0
# ...      ...                 ...         ...            ...            ...
# 67291  43435              Sydney       Wuhan          China         1449.0
# 67292  43435              Sydney      Xiamen          China         2878.0
# 67293  43435              Sydney       Xi'an          China         2076.0
# 67294  43435              Sydney   Zhengzhou          China          989.0
# 67295  43435  Toowoomba Wellcamp   Hong Kong  Hong Kong SAR            0.0
#
#        Passengers_Out  Passengers_Total  Year  Month_num  \
# ...

# %% [markdown]
# Saving the dataframe to a csv file

# %%
aviation_economy.to_csv("aviation_economy.csv")
